# %% [markdown]
# # Drifting Model
#
# Generative Modeling via Drifting, Deng et al., 2026. [arXiv:2602.04770](https://arxiv.org/abs/2602.04770)
#
# ## 1. Prepare Dataset
#
# Define the gaussian mixture distribution as the target distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

from utils import gmm

X, Y = gmm(100000, weights=[0.3, 0.7], mean=[-0.5, 1.0], std=[0.1, 0.2])

_ = plt.hist(X, bins=np.linspace(-5, 5, 200), label="data")

# %% [markdown]
# ## 2. Define Model
#
# Define MLP backbone and Drifting Model framework.

# %%
from flowmodels.drifting import DriftingModel
from utils import Backbone


COND = False
aux = 0 if not COND else 1
model = DriftingModel(Backbone(aux=aux), prior_dim=aux + 1, temps=0.2)
model
# Out:
# DriftingModel(
#   (generator): Backbone(
#     (net): Sequential(
#       (0): Linear(in_features=1, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=64, out_features=64, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## 3. Training Drifting Model
#
# Train the Drifting Model with the prepared dataset.

# %%
import torch
from tqdm.auto import tqdm

from utils import vis

# training configurations
LR = 0.001
TRAIN_STEPS = 1000
BATCH_SIZE = 2048

# train
model.train()
optim = torch.optim.Adam(model.parameters(), LR)

losses = []
with tqdm(range(TRAIN_STEPS)) as pbar:
    for i in pbar:
        indices = torch.randint(0, len(X), (BATCH_SIZE,))
        loss = model.loss(
            sample=X[indices],
            label=Y[indices] if COND else None,
        )
        # update
        optim.zero_grad()
        loss.backward()
        optim.step()

        # log
        losses.append(loss.detach().item())
        pbar.set_postfix_str(f"loss: {loss:.2f}")

plt.plot(losses)
vis(model, conditional=COND, steps=[1])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# ## 4. W-Flow with Sinkhorn divergence
#
# One-Step Generative Modeling via Wasserstein Gradient Flows. [arXiv:2605.11755](https://arxiv.org/abs/2605.11755)

# %%
import torch
from tqdm.auto import tqdm

from flowmodels.drifting import WFlowSinkhornDrift
from utils import vis

# training configurations
LR = 0.001
TRAIN_STEPS = 1000
BATCH_SIZE = 2048

# train
model = WFlowSinkhornDrift(Backbone(aux=aux), prior_dim=aux + 1, temps=0.2)
model.train()
optim = torch.optim.Adam(model.parameters(), LR)

losses = []
with tqdm(range(TRAIN_STEPS)) as pbar:
    for i in pbar:
        indices = torch.randint(0, len(X), (BATCH_SIZE,))
        loss = model.loss(
            sample=X[indices],
            label=Y[indices] if COND else None,
        )
        # update
        optim.zero_grad()
        loss.backward()
        optim.step()

        # log
        losses.append(loss.detach().item())
        pbar.set_postfix_str(f"loss: {loss:.2f}")

plt.plot(losses)
vis(model, conditional=COND, steps=[1])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
